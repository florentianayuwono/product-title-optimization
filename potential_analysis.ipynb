# %%
# Import packages
import pandas as pd
import os
import numpy as np

# %%
# Load data
local_df = pd.read_csv(os.path.join('../data', 'motorcycleaccessories_local.csv'))
local_df = local_df.drop(['shop_id', 'item_id', 'source', 'level2_global_be_category'], axis=1)
local_df = local_df[local_df['total_sales'] > 0]
# local_df = local_df[local_df['price'] < 100000]

cb_df = pd.read_csv(os.path.join('../data', 'motorcycleaccessories_cb.csv'))
cb_df = cb_df.drop(['shop_id', 'item_id', 'source', 'level2_global_be_category'], axis=1)
cb_df = cb_df[cb_df['total_sales'] > 0]
# cb_df = cb_df[cb_df['price'] < 100000]

# %%
cb_df
# Out:
#      total_sales                                      product_title     price
# 0           5113  1pc Kaca Spion Cembung Wide Angle Adjustable U...   40277.0
# 1           2684  Kondom kunci Remote Mobil Honda Beat Vario Sup...   14385.0
# 2           2489  【Flash Sale】Braket Stand Holder Segitiga untuk...   17262.0
# 3           2465  Helm Lampu LED Sein Strip Tahan Air untuk Moto...   75951.0
# 4           1967  Klip Body Nmax dan motor Universal（beli 40 gra...    2762.0
# ..           ...                                                ...       ...
# 995            0  Kunci Rem Stang Motor / Skuter Anti Maling War...  179014.0
# 996            0  (FF) Kaos T-Shirt Lengan Pendek Motif Print Un...    9298.0
# 997            0  1pcs Universal Motor Sudut Kanan Inline Fuel F...   21865.0
# 998            0  Electric Scooter Reflective Sticker Skate Warn...   42579.0
# 999            0  Kunci Sepeda Motor Universal Bentuk U Anti Mal...  420033.0
#
# [1000 rows x 3 columns]

# %%
local_total_sales = local_df['total_sales'].values
cb_total_sales = cb_df['total_sales'].values

local_avg_price = local_df['price'].mean()
cb_avg_price = cb_df['price'].mean()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 4))

# Create boxplots to identify outliers
sns.boxplot(data=[local_total_sales, cb_total_sales])
plt.xticks([0, 1], ['Local', 'Cross-Border'])
plt.xlabel('Product Type')
plt.ylabel('Total Sales')
plt.title('Identification of Outliers')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.kdeplot(local_total_sales, fill=True, label='Local')
sns.kdeplot(cb_total_sales, fill=True, label='Cross-Border')

# Set plot labels
plt.xlabel('Total Sales')
plt.ylabel('Density')
plt.title('Distribution of Total Sales')

# Show the legend
plt.legend()

# Display the plot
plt.show()

# %%
plt.figure(figsize=(8, 6))

sns.scatterplot(data=local_df, x='price', y='total_sales')

# Set plot labels
plt.xlabel('Price')
plt.ylabel('Total Sales')
plt.title('Correlation between Price and Total Sales')

# Display the plot
plt.show()

correlation_coef = local_df['price'].corr(local_df['total_sales'])
print("Pearson correlation coeff:", correlation_coef)
# Out:
# Pearson correlation coeff: -0.10317501666783818

# %%
plt.figure(figsize=(8, 6))

sns.scatterplot(data=cb_df, x='price', y='total_sales')

# Set plot labels
plt.xlabel('Price')
plt.ylabel('Total Sales')
plt.title('Correlation between Price and Total Sales')

# Display the plot
plt.show()

correlation_coef = cb_df['price'].corr(cb_df['total_sales'])
print("Pearson correlation coeff:", correlation_coef)
# Out:
# Pearson correlation coeff: -0.07734121768047027

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))

# Separate the data points into two groups: local products and cross-border products
local_df = local_df[local_df['price'] < 200000]
local_df = local_df[local_df['total_sales'] < 50000]
cb_df = cb_df[cb_df['price'] < 200000]

local_prices = local_df['price']
local_sales = local_df['total_sales']

crossborder_prices = cb_df['price']
crossborder_sales = cb_df['total_sales']

# Create a scatter plot
plt.scatter(local_prices, local_sales, color='blue', edgecolors='white', label='Local Products')
plt.scatter(crossborder_prices, crossborder_sales, color='orange', edgecolors='white',  label='Cross-border Products')

# Set the labels and title
plt.xlabel('Price')
plt.ylabel('Total Sales')
plt.title('Correlation between Price and Total Sales')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
cb_df
# Out:
#      total_sales                                      product_title     price
# 0           5113  1pc Kaca Spion Cembung Wide Angle Adjustable U...   40277.0
# 1           2684  Kondom kunci Remote Mobil Honda Beat Vario Sup...   14385.0
# 2           2489  【Flash Sale】Braket Stand Holder Segitiga untuk...   17262.0
# 3           2465  Helm Lampu LED Sein Strip Tahan Air untuk Moto...   75951.0
# 4           1967  Klip Body Nmax dan motor Universal（beli 40 gra...    2762.0
# ..           ...                                                ...       ...
# 469            1  Luckyx M5 Stand Holder Magnetik Universal Flex...  194768.0
# 471            1  Adawnshbhyu Base Clamp Bola 1 25mm Dengan Sekr...   58436.0
# 472            1  (Newwavebar & 3c) Knob Pin Pengunci Anti Malin...   42694.0
# 473            1  Miquel Worm Gears Roda Gigi Cog Satu Lapis M0....   45801.0
# 474            1  KENTON Ergonomic Seat Cushion Motorcycle Seat ...  179521.0
#
# [430 rows x 3 columns]
