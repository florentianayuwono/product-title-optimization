# %%
# Import packages
import pandas as pd
import os
import numpy as np

# Load data
df = pd.read_csv(os.path.join('../data', 'test.csv'))
df
# Out:
#                             Product Category  \
# 0                                        NaN
# 1     Sports & Outdoor Recreation Equipments
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 1505                                     NaN
# 1506                                     NaN
# 1507                                     NaN
# 1508                                     NaN
# 1509                                     NaN
#
#                                           Product Title  \
# 0                                                   NaN
# 1     Pancing Reel Spinning Fishing Reel 1000-7000 5...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# ...

# %%
df['Product Category'] = df['Product Category'].fillna(method='ffill')
df
# Out:
#                             Product Category  \
# 0                                        NaN
# 1     Sports & Outdoor Recreation Equipments
# 2     Sports & Outdoor Recreation Equipments
# 3     Sports & Outdoor Recreation Equipments
# 4     Sports & Outdoor Recreation Equipments
# ...                                      ...
# 1505                         Home Organizers
# 1506                         Home Organizers
# 1507                         Home Organizers
# 1508                         Home Organizers
# 1509                         Home Organizers
#
#                                           Product Title  \
# 0                                                   NaN
# 1     Pancing Reel Spinning Fishing Reel 1000-7000 5...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# ...

# %%
transposed_df = pd.pivot_table(df, index='Product Title', columns='Unnamed: 4',
                               aggfunc=lambda x: 1 if x.notna().any() else 0,
                               fill_value=0).reset_index()
# Flatten the column names
transposed_df.columns = ['Product Title'] + [f'Unnamed: 4_{col}' for col in transposed_df.columns[1:]]
transposed_df
# Out:
#                                        Product Title  \
# 0  Pancing Reel Spinning Fishing Reel 1000-7000 5...
#
#    Unnamed: 4_('Product Category', 'None')  \
# 0                                        1
#
#    Unnamed: 4_('Product Image URL', 'None')  \
# 0                                         1
#
#    Unnamed: 4_('Score (1 - 5) and Classification', 'None')  \
# 0                                                  1
#
#    Unnamed: 4_('Unnamed: 10', 'None')  Unnamed: 4_('Unnamed: 5', 'None')  \
# 0                                   0                                  0
#
#    Unnamed: 4_('Unnamed: 6', 'None')  Unnamed: 4_('Unnamed: 7', 'None')  \
# 0                                  0                                  0
#
#    Unnamed: 4_('Unnamed: 8', 'None')  Unnamed: 4_('Unnamed: 9', 'None')
# 0                                  0                                  0
