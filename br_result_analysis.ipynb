# %%
# Import packages
import pandas as pd
import os
import numpy as np

# %%
# Load data
br_result = pd.read_csv(os.path.join('../data', 'BR-Results.csv'))
br_result
# Out:
#     level2_global_be_category level1_global_be_category  uo_uu_difference  \
# 0                      Gloves       Fashion Accessories          0.001313
# 1     Shoe Care & Accessories                 Men Shoes          0.001295
# 2     Shoe Care & Accessories               Women Shoes          0.001203
# 3                      Others                   Watches          0.001116
# 4         Printers & Scanners   Computers & Accessories          0.000923
# ..                        ...                       ...               ...
# 112               Camera Care          Cameras & Drones         -0.000366
# 113                    Others                      Pets         -0.000400
# 114             Vinyl Records     Hobbies & Collections         -0.000450
# 115                   Laptops   Computers & Accessories         -0.000652
# 116     Maternity Accessories                Mom & Baby         -0.000682
#
#      uo_sum  uu_sum   price_avg  price_mid  uo_sum.1  uu_sum.1  price_avg.1  \
# ...

# %%
potential_categories = br_result[br_result['uo_uu_cb'] > br_result['uo_uu_local']]
potential_categories
# Out:
#        level2_global_be_category level1_global_be_category  uo_uu_difference  \
# 97                        Others                    Beauty     -8.362071e-07
# 98                       Cameras          Cameras & Drones     -2.304888e-05
# 99              Lens Accessories          Cameras & Drones     -3.591210e-05
# 100            Diapering & Potty                Mom & Baby     -4.297377e-05
# 101       Baby Travel Essentials                Mom & Baby     -4.342103e-05
# 102      Baby Mittens & Footwear       Baby & Kids Fashion     -4.486670e-05
# 103                       Others             Home & Living     -4.973402e-05
# 104  Accessories Sets & Packages       Fashion Accessories     -8.765678e-05
# 105                 Beauty Tools                    Beauty     -8.843862e-05
# 106                      Anklets       Fashion Accessories     -1.011362e-04
# 107         Gift Sets & Packages                Mom & Baby     -1.519552e-04
# ...
