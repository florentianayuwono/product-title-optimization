# %%
# Import packages
import pandas as pd
import os
import numpy as np

# %%
# Load data
local_df = pd.read_csv(os.path.join('../data', 'petclothing_local.csv'))
local_df = local_df.drop(['shop_id', 'item_id', 'source', 'level2_global_be_category'], axis=1)

cb_df = pd.read_csv(os.path.join('../data', 'petclothing_cb.csv'))
cb_df = cb_df.drop(['shop_id', 'item_id', 'source', 'level2_global_be_category'], axis=1)

# %%
cb_df
# Out:
#      total_sales                                      product_title    price
# 0           5977  mulitcolor lovely small Kalung Hewan Anak Kuci...  12083.0
# 1           5665  Strap Extender Bahan Anti Slip Adjustable Untu...   5754.0
# 2           3783  Phoenixshop Kalung Anjing/Kucing Kecil Bahan N...  16111.0
# 3           3685  Kalung Leher Adjustable Anti Kutu Warna Merah ...  17722.0
# 4           2688  [COD] CACTU Kalung Anjing / Kucing 2 Lapis Bah...  19333.0
# ..           ...                                                ...      ...
# 995            0  Puppy Vest Top Lovely Apparel Lucu Lembut Hadi...  69046.0
# 996            0  June Kacamata Hitam Anjing Kecil Kucing Anjing...  66285.0
# 997            0  UH 6Pcs Cute Hat Dog Puppy Model Figurine Desk...  47953.0
# 998            0  10pcs Pita Motif Print Handmade Untuk Dekorasi...  35674.0
# 999            0  Topi Wig Keriting Untuk Aksesoris Hewan Peliha...  49976.0
#
# [1000 rows x 3 columns]

# %%
local_total_sales = local_df['total_sales'].values
cb_total_sales = cb_df['total_sales'].values

local_avg_price = local_df['price'].mean()
cb_avg_price = cb_df['price'].mean()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 4))

# Create boxplots to identify outliers
sns.boxplot(data=[local_total_sales, cb_total_sales])
plt.xticks([0, 1], ['Local', 'Cross-Border'])
plt.xlabel('Product Type')
plt.ylabel('Total Sales')
plt.title('Identification of Outliers')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.kdeplot(local_total_sales, fill=True, label='Local')
sns.kdeplot(cb_total_sales, fill=True, label='Cross-Border')

# Set plot labels
plt.xlabel('Total Sales')
plt.ylabel('Density')
plt.title('Distribution of Total Sales')

# Show the legend
plt.legend()

# Display the plot
plt.show()

# %%
plt.figure(figsize=(8, 6))

sns.scatterplot(data=local_df, x='price', y='total_sales')

# Set plot labels
plt.xlabel('Price')
plt.ylabel('Total Sales')
plt.title('Correlation between Price and Total Sales')

# Display the plot
plt.show()

correlation_coef = local_df['price'].corr(local_df['total_sales'])
print("Pearson correlation coeff:", correlation_coef)
# Out:
# Pearson correlation coeff: -0.03043451917774221

# %%
plt.figure(figsize=(8, 6))

sns.scatterplot(data=cb_df, x='price', y='total_sales')

# Set plot labels
plt.xlabel('Price')
plt.ylabel('Total Sales')
plt.title('Correlation between Price and Total Sales')

# Display the plot
plt.show()

correlation_coef = cb_df['price'].corr(cb_df['total_sales'])
print("Pearson correlation coeff:", correlation_coef)
# Out:
# Pearson correlation coeff: -0.06318387225801556
